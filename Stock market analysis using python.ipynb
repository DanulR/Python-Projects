# %%
import pandas as pd

# %%
df = pd.read_csv("AMZN.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 1  2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2  2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 3  2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 4  2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
#
#      Volume
# 0  68523600
# 1  87775600
# 2  70691900
# 3  66527300
# 4  80450100

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(figsize=(20,10))
df['Date']=pd.to_datetime(df['Date'])
sns.lineplot(x='Date',y='Adj Close',data=df)
plt.xticks(rotation=45)
ax.set_xlabel('time',fontsize=15)
ax.set_ylabel('change in stock price',fontsize=15)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(20,10))
df['Date']=pd.to_datetime(df['Date'])
sns.lineplot(x='Date',y='Volume',data=df)
ax.set_xlabel('time',fontsize=15)
ax.set_ylabel('change in volume',fontsize=15)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date',inplace=True)
df['Mov Avg']=df['Close'].rolling(30).mean()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
# ...                ...         ...         ...         ...         ...
# 2024-01-19  153.830002  155.759995  152.740005  155.339996  155.339996
# 2024-01-22  156.889999  157.050003  153.899994  154.779999  154.779999
# 2024-01-23  154.850006  156.210007  153.929993  156.020004  156.020004
# 2024-01-24  157.800003  158.509995  156.479996  156.869995  156.869995
# 2024-01-25  156.949997  158.509995  154.550003  157.750000  157.750000
#
#               Volume     Mov Avg
# Date
# 2023-01-26  68523600         NaN
# 2023-01-27  87775600         NaN
# ...

# %%
df[['Close','Mov Avg']].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df['Daily Return'] = df['Close'].pct_change()*100

# %%
dailyReturnAverage = df['Daily Return'].mean()
print(f'Daily return average of Amazon is:{dailyReturnAverage:2f}%')
# Out:
# Daily return average of Amazon is:0.205699%

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
# ...                ...         ...         ...         ...         ...
# 2024-01-19  153.830002  155.759995  152.740005  155.339996  155.339996
# 2024-01-22  156.889999  157.050003  153.899994  154.779999  154.779999
# 2024-01-23  154.850006  156.210007  153.929993  156.020004  156.020004
# 2024-01-24  157.800003  158.509995  156.479996  156.869995  156.869995
# 2024-01-25  156.949997  158.509995  154.550003  157.750000  157.750000
#
#               Volume     Mov Avg  Daily Return
# Date
# 2023-01-26  68523600         NaN           NaN
# ...

# %%
def trend(x):
    if x>0:
        return 'Positive'
    elif x<0:
        return 'Negative'
    else:
        return 'Neutral'

df['Trend'] = df['Daily Return'].apply(trend)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
# ...                ...         ...         ...         ...         ...
# 2024-01-19  153.830002  155.759995  152.740005  155.339996  155.339996
# 2024-01-22  156.889999  157.050003  153.899994  154.779999  154.779999
# 2024-01-23  154.850006  156.210007  153.929993  156.020004  156.020004
# 2024-01-24  157.800003  158.509995  156.479996  156.869995  156.869995
# 2024-01-25  156.949997  158.509995  154.550003  157.750000  157.750000
#
#               Volume     Mov Avg  Daily Return     Trend
# Date
# ...

# %%
count = df['Trend'].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index)
plt.show()

# %%
amzn = pd.read_csv('AMZN.csv')

# %%
app = pd.read_csv('AAPL.csv')

# %%
goog = pd.read_csv('GOOG.csv')

# %%
msft = pd.read_csv('MSFT.csv')

# %%
fig,ax = plt.subplots(figsize=(20,15))
amzn['Date']=pd.to_datetime(amzn['Date'])
app['Date']=pd.to_datetime(app['Date'])
goog['Date']=pd.to_datetime(goog['Date'])
msft['Date']=pd.to_datetime(msft['Date'])
sns.lineplot(x='Date',y='Close',data=app,label='Apple')
sns.lineplot(x='Date',y='Close',data=amzn,label='Amazon')
sns.lineplot(x='Date',y='Close',data=goog,label='Google')
sns.lineplot(x='Date',y='Close',data=msft,label='Microsoft')
plt.xticks(rotation=45)
ax.set_xlabel('time',fontsize=15)
ax.set_ylabel('change in stock price',fontsize=15)
plt.show()

# %%
#There is a high change in price in the google stock while other stock prices only has a slight increase in their prices

# %%
fig,axes = plt.subplots(2,2,figsize=(20,10))

sns.lineplot(x='Date',y='Volume',data=app,label='Apple',ax=axes[0,0],color='blue')
sns.lineplot(x='Date',y='Volume',data=amzn,label='Amazon',ax=axes[0,1],color='orange')
sns.lineplot(x='Date',y='Volume',data=goog,label='Google',ax=axes[1,0],color='red')
sns.lineplot(x='Date',y='Volume',data=msft,label='Microsoft',ax=axes[1,1],color='green')

for ax in axes.flat:
    ax.set_xlabel('time',fontsize=15)
    ax.set_ylabel('change in volume',fontsize=15)
    



plt.show()

# %%
#The volume traded of google and apple remained clost to same while there is a drop in the volume traded with the Amazon stock.
#There is a slight drop in the volume traded with the microsoft stock.

# %%
app.set_index('Date',inplace=True)
app['Mov Avg']=df['Close'].rolling(30).mean()
app
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26  143.169998  144.250000  141.899994  143.960007  143.159805
# 2023-01-27  143.160004  147.229996  143.080002  145.929993  145.118851
# 2023-01-30  144.960007  145.550003  142.850006  143.000000  142.205154
# 2023-01-31  142.699997  144.339996  142.279999  144.289993  143.487961
# 2023-02-01  143.970001  146.610001  141.320007  145.429993  144.621628
# ...                ...         ...         ...         ...         ...
# 2024-01-19  189.330002  191.949997  188.820007  191.559998  191.559998
# 2024-01-22  192.300003  195.330002  192.259995  193.889999  193.889999
# 2024-01-23  195.020004  195.750000  193.830002  195.179993  195.179993
# 2024-01-24  195.419998  196.380005  194.339996  194.500000  194.500000
# 2024-01-25  195.220001  196.270004  193.110001  194.169998  194.169998
#
#               Volume     Mov Avg
# Date
# 2023-01-26  54105100         NaN
# 2023-01-27  70555800         NaN
# ...

# %%
amzn.set_index('Date',inplace=True)
amzn['Mov Avg']=df['Close'].rolling(30).mean()
amzn
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
# ...                ...         ...         ...         ...         ...
# 2024-01-19  153.830002  155.759995  152.740005  155.339996  155.339996
# 2024-01-22  156.889999  157.050003  153.899994  154.779999  154.779999
# 2024-01-23  154.850006  156.210007  153.929993  156.020004  156.020004
# 2024-01-24  157.800003  158.509995  156.479996  156.869995  156.869995
# 2024-01-25  156.949997  158.509995  154.550003  157.750000  157.750000
#
#               Volume     Mov Avg
# Date
# 2023-01-26  68523600         NaN
# 2023-01-27  87775600         NaN
# ...

# %%
goog.set_index('Date',inplace=True)
goog['Mov Avg']=df['Close'].rolling(30).mean()
goog
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.279999   99.209999   96.820000   99.160004   99.160004
# 2023-01-27   99.050003  101.580002   98.970001  100.709999  100.709999
# 2023-01-30   98.745003   99.408997   97.519997   97.949997   97.949997
# 2023-01-31   97.860001   99.910004   97.790001   99.870003   99.870003
# 2023-02-01   99.739998  102.190002   98.419998  101.430000  101.430000
# ...                ...         ...         ...         ...         ...
# 2024-01-19  146.304993  148.039993  145.800003  147.970001  147.970001
# 2024-01-22  148.710007  150.014999  147.580002  147.710007  147.710007
# 2024-01-23  147.720001  148.860001  147.190002  148.679993  148.679993
# 2024-01-24  150.289993  151.570007  149.839996  150.350006  150.350006
# 2024-01-25  151.740005  154.759995  151.220001  153.639999  153.639999
#
#               Volume     Mov Avg
# Date
# 2023-01-26  24542100         NaN
# 2023-01-27  29020400         NaN
# ...

# %%
msft.set_index('Date',inplace=True)
msft['Mov Avg']=df['Close'].rolling(30).mean()

# %%
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26  243.649994  248.309998  242.000000  248.000000  245.820328
# 2023-01-27  248.990005  249.830002  246.830002  248.160004  245.978943
# 2023-01-30  244.509995  245.600006  242.199997  242.710007  240.576843
# 2023-01-31  243.449997  247.949997  242.949997  247.809998  245.631989
# 2023-02-01  248.000000  255.179993  245.470001  252.750000  250.528580
# ...                ...         ...         ...         ...         ...
# 2024-01-19  395.760010  398.670013  393.500000  398.670013  398.670013
# 2024-01-22  400.019989  400.619995  393.589996  396.510010  396.510010
# 2024-01-23  395.750000  399.380005  393.929993  398.899994  398.899994
# 2024-01-24  401.540009  405.630005  400.450012  402.559998  402.559998
# 2024-01-25  404.320007  407.010010  402.529999  404.869995  404.869995
#
#               Volume     Mov Avg
# Date
# 2023-01-26  33454500         NaN
# 2023-01-27  26498900         NaN
# ...

# %%
fig,axes = plt.subplots(2,2,figsize=(20,20))
app[['Close','Mov Avg']].plot(ax=axes[0,0],title='Apple')
amzn[['Close','Mov Avg']].plot(ax=axes[0,1],title='Amazon')
goog[['Close','Mov Avg']].plot(ax=axes[1,0],title='Google')
msft[['Close','Mov Avg']].plot(ax=axes[1,1],title='Microsoft')
plt.legend()

for ax in axes.flat:
    ax.set_title(ax.get_title(), fontsize=16)
    
for ax in axes.flat:
    ax.set_ylabel('price',fontsize=13)
    
for ax in axes.flat:
    ax.set_xlabel('Date',fontsize=13)
    
plt.show()

# %%
#The moving averages of Apple, Amazon and Google is showing fluctuations in the curve while we microsoft has a smooth curve

# %%
app['Daily Return'] = app['Close'].pct_change()*100
amzn['Daily Return'] = amzn['Close'].pct_change()*100
goog['Daily Return'] = goog['Close'].pct_change()*100
msft['Daily Return'] = msft['Close'].pct_change()*100

# %%
dailyReturnAverageApp = app['Daily Return'].mean()
print(f'Daily return average of Apple is:{dailyReturnAverageApp:2f}%')
# Out:
# Daily return average of Apple is:0.127721%

# %%
dailyReturnAverageAmzn = amzn['Daily Return'].mean()
print(f'Daily return average of Amazon is:{dailyReturnAverageAmzn:2f}%')
# Out:
# Daily return average of Amazon is:0.205699%

# %%
dailyReturnAverageGoog = goog['Daily Return'].mean()
print(f'Daily return average of Google is:{dailyReturnAverageGoog:2f}%')
# Out:
# Daily return average of Google is:0.192740%

# %%
dailyReturnAverageMsft = msft['Daily Return'].mean()
print(f'Daily return average of Microsoft is:{dailyReturnAverageMsft:2f}%')
# Out:
# Daily return average of Microsoft is:0.207461%

# %%
lst = [dailyReturnAverageApp,dailyReturnAverageAmzn,dailyReturnAverageGoog,dailyReturnAverageMsft]

# %%
dar = pd.DataFrame(lst,index=['Apple','Amazon','Google','Microsoft'])
dar = dar.rename(columns={0: 'Daily Return Avg'})

# %%
dar
# Out:
#            Daily Return Avg
# Apple              0.127721
# Amazon             0.205699
# Google             0.192740
# Microsoft          0.207461

# %%
dar.plot(kind='bar',legend=False)
# Out:
# <Axes: >

# %%
#Amazon and Microsoft's daily return average is virtually identicle while Apple has the lowest daily return average

# %%
def trend(x):
    if x>0:
        return 'Positive'
    elif x<0:
        return 'Negative'
    else:
        return 'Neutral'

app['Trend'] = app['Daily Return'].apply(trend)
app
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26  143.169998  144.250000  141.899994  143.960007  143.159805
# 2023-01-27  143.160004  147.229996  143.080002  145.929993  145.118851
# 2023-01-30  144.960007  145.550003  142.850006  143.000000  142.205154
# 2023-01-31  142.699997  144.339996  142.279999  144.289993  143.487961
# 2023-02-01  143.970001  146.610001  141.320007  145.429993  144.621628
# ...                ...         ...         ...         ...         ...
# 2024-01-19  189.330002  191.949997  188.820007  191.559998  191.559998
# 2024-01-22  192.300003  195.330002  192.259995  193.889999  193.889999
# 2024-01-23  195.020004  195.750000  193.830002  195.179993  195.179993
# 2024-01-24  195.419998  196.380005  194.339996  194.500000  194.500000
# 2024-01-25  195.220001  196.270004  193.110001  194.169998  194.169998
#
#               Volume     Mov Avg  Daily Return     Trend
# Date
# ...

# %%
count_app = app['Trend'].value_counts()

# %%
def trend(x):
    if x>0:
        return 'Positive'
    elif x<0:
        return 'Negative'
    else:
        return 'Neutral'

amzn['Trend'] = amzn['Daily Return'].apply(trend)
amzn
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.239998   99.489998   96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998   99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998   99.010002  100.550003  100.550003
# 2023-01-31  101.160004  103.349998  101.139999  103.129997  103.129997
# 2023-02-01  102.529999  106.239998  101.239998  105.150002  105.150002
# ...                ...         ...         ...         ...         ...
# 2024-01-19  153.830002  155.759995  152.740005  155.339996  155.339996
# 2024-01-22  156.889999  157.050003  153.899994  154.779999  154.779999
# 2024-01-23  154.850006  156.210007  153.929993  156.020004  156.020004
# 2024-01-24  157.800003  158.509995  156.479996  156.869995  156.869995
# 2024-01-25  156.949997  158.509995  154.550003  157.750000  157.750000
#
#               Volume     Mov Avg  Daily Return     Trend
# Date
# ...

# %%
count_amzn = amzn['Trend'].value_counts()

# %%
def trend(x):
    if x>0:
        return 'Positive'
    elif x<0:
        return 'Negative'
    else:
        return 'Neutral'

goog['Trend'] = goog['Daily Return'].apply(trend)
goog
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26   98.279999   99.209999   96.820000   99.160004   99.160004
# 2023-01-27   99.050003  101.580002   98.970001  100.709999  100.709999
# 2023-01-30   98.745003   99.408997   97.519997   97.949997   97.949997
# 2023-01-31   97.860001   99.910004   97.790001   99.870003   99.870003
# 2023-02-01   99.739998  102.190002   98.419998  101.430000  101.430000
# ...                ...         ...         ...         ...         ...
# 2024-01-19  146.304993  148.039993  145.800003  147.970001  147.970001
# 2024-01-22  148.710007  150.014999  147.580002  147.710007  147.710007
# 2024-01-23  147.720001  148.860001  147.190002  148.679993  148.679993
# 2024-01-24  150.289993  151.570007  149.839996  150.350006  150.350006
# 2024-01-25  151.740005  154.759995  151.220001  153.639999  153.639999
#
#               Volume     Mov Avg  Daily Return     Trend
# Date
# ...

# %%
count_goog = goog['Trend'].value_counts()

# %%
def trend(x):
    if x>0:
        return 'Positive'
    elif x<0:
        return 'Negative'
    else:
        return 'Neutral'

msft['Trend'] = msft['Daily Return'].apply(trend)
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-26  243.649994  248.309998  242.000000  248.000000  245.820328
# 2023-01-27  248.990005  249.830002  246.830002  248.160004  245.978943
# 2023-01-30  244.509995  245.600006  242.199997  242.710007  240.576843
# 2023-01-31  243.449997  247.949997  242.949997  247.809998  245.631989
# 2023-02-01  248.000000  255.179993  245.470001  252.750000  250.528580
# ...                ...         ...         ...         ...         ...
# 2024-01-19  395.760010  398.670013  393.500000  398.670013  398.670013
# 2024-01-22  400.019989  400.619995  393.589996  396.510010  396.510010
# 2024-01-23  395.750000  399.380005  393.929993  398.899994  398.899994
# 2024-01-24  401.540009  405.630005  400.450012  402.559998  402.559998
# 2024-01-25  404.320007  407.010010  402.529999  404.869995  404.869995
#
#               Volume     Mov Avg  Daily Return     Trend
# Date
# ...

# %%
count_msft = msft['Trend'].value_counts()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2, 2, 1)
plt.pie(count_app,labels=count_app.index,autopct="%1.1f%%")
plt.title('Apple')
plt.subplot(2, 2, 2)
plt.pie(count_amzn,labels=count_amzn.index,autopct="%1.1f%%")
plt.title('Amazon')
plt.subplot(2, 2, 3)
plt.pie(count_goog,labels=count_amzn.index,autopct="%1.1f%%")
plt.title('Google')
plt.subplot(2, 2, 4)
plt.pie(count_msft,labels=count_amzn.index,autopct="%1.1f%%")
plt.title('Microsoft')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Out of the 4 stocks, Microsoft has the highest positve trend with 55.0% while Amazon,Apple and Google follow with a 
#positive trend of 53.8%,53.4%,53.0% respectively

# %%
new_df = pd.concat([app['Daily Return'],amzn['Daily Return'],goog['Daily Return'],msft['Daily Return']],axis=1)

# %%
new_df.columns = ['Apple','Amazon','Google','Microsoft']

# %%
new_df
# Out:
#                Apple    Amazon    Google  Microsoft
# Date
# 2023-01-26       NaN       NaN       NaN        NaN
# 2023-01-27  1.368426  3.043738  1.563125   0.064518
# 2023-01-30 -2.007807 -1.652969 -2.740544  -2.196163
# 2023-01-31  0.902093  2.565882  1.960190   2.101269
# 2023-02-01  0.790076  1.958698  1.562028   1.993464
# ...              ...       ...       ...        ...
# 2024-01-19  1.553302  1.198694  2.055311   1.218681
# 2024-01-22  1.216330 -0.360498 -0.175707  -0.541802
# 2024-01-23  0.665323  0.801140  0.656683   0.602755
# 2024-01-24 -0.348393  0.544796  1.123226   0.917524
# 2024-01-25 -0.169667  0.560977  2.188223   0.573827
#
# [251 rows x 4 columns]

# %%
correlation = new_df.corr()

# %%
correlation
# Out:
#               Apple    Amazon    Google  Microsoft
# Apple      1.000000  0.432730  0.527302   0.553591
# Amazon     0.432730  1.000000  0.611669   0.567927
# Google     0.527302  0.611669  1.000000   0.506633
# Microsoft  0.553591  0.567927  0.506633   1.000000

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
#Among these 4 stocks, Amazon and Google has the highest correlation with a value of 0.61 while Amazon and Microsoft has a 
#correlation of 0.57 and Google and Apple follows with 0.55, Google and Apple with 0.53 and the correlation between Amazon and 
#Apple being the lowest with a correlation of 0.43
